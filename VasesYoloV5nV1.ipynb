# %%
# Установка зависимостей
# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5
# %pip install -qr requirements.txt comet_ml

import torch
import utils
display = utils.notebook_init()
# Out:
# YOLOv5 🚀 v7.0-416-gfe1d4d99 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 41.5/112.6 GB disk)

# %%
# Загрузка датасета
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="API_KEY")
project = rf.workspace("vkpersonal").project("hermitagevases")
version = project.version(1)
dataset = version.download("yolov5")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.3/85.3 kB 5.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 14.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 140.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.11.0.86
#     Uninstalling opencv-python-headless-4.11.0.86:
#       Successfully uninstalled opencv-python-headless-4.11.0.86
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to HermitageVases-1 in yolov5pytorch:: 100%|██████████| 4380/4380 [00:00<00:00, 7705.09it/s]

# %%
# Тренировка
# !python train.py --img 640 --batch 16 --epochs 50 --data dataset/data.yaml --cfg models/yolov5n.yaml --weights yolov5n.pt --name yolov5nV1 --cache
# Out:
# 2025-05-09 11:25:44.963209: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746789944.983388    6823 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746789944.989807    6823 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# Валидация
# !python val.py --weights runs/train/yolov5nV13/weights/best.pt --data dataset/data.yaml --task test --img 640

# %%
# Скачивания zip архива на компьютер
# !zip -r yolov5n /content/yolov5

from google.colab import files
files.download("yolov5n.zip")

# %%
# Экспорт в формат CoreML
# %cd yolov5

# !pip install coremltools
# !python export.py --weights runs/train/yolov5nV13/weights/best.pt --include coreml
